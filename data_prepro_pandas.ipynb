# %%
# Pandas

# %%
# %pip install pandas
# Out:
# ...
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1D data structures in Pandas

# %%
# Pandas Series

# %%
# A Pandas Series is a one-dimensional labeled array capable of holding 
# any data type (integers, strings, floats, Python objects, etc.).

# Each element has:
# Data (values)
# Label (index)

# %%
# Creating a Pandas Series

# %%
# 1. From a List

# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# 2. With Custom Index

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# 3. From a Dictionary

# %%
data = {'a': 10, 'b': 20, 'c': 30}
s = pd.Series(data)

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# 4. From a Single Value

# %%
s = pd.Series(5, index=[0,1,2,3])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
# Important Attributes

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values   # returns data
# Out:
# array([10, 20, 30])

# %%
s.index    # returns index labels
# Out:
# Index(['a', 'b', 'c'], dtype='str')

# %%
s.dtype    # data type
# Out:
# dtype('int64')

# %%
s.shape    # size (1D)
# Out:
# (3,)

# %%
# Basic Data Manipulation

# %%
# 1. Arithmetic Operations

# %%
s = pd.Series([1,2,3])
print(s * 2)
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
# 2. Handling Missing Values

# %%
s = pd.Series([1, None, 3])

# %%
s.isnull()     # detect missing
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()     # remove missing
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(0)    # replace missing
# Out:
# 0    1.0
# 1    0.0
# 2    3.0
# dtype: float64

# %%
# Value Counts

# %%
s = pd.Series([1,2,2,3,3,3])
s.value_counts()
# Out:
# 3    3
# 2    2
# 1    1
# Name: count, dtype: int64

# %%
# Indexing

# %%
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
# Indexing by Label

# %%
s['a']
# Out:
# np.int64(10)

# %%
# 2D data structures in Pandas

# %%
data = {
    "Customer_ID": [101, 102, 103, 104, 105],
    "Name": ["Rahul", "Amit", "Sneha", "Priya", "Kiran"],
    "Age": [25, 30, None, 28, 40],
    "City": ["Pune", "Mumbai", "Pune", "Delhi", "Mumbai"],
    "Salary": [50000, 60000, 55000, None, 65000]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    Customer_ID   Name   Age    City   Salary
# 0          101  Rahul  25.0    Pune  50000.0
# 1          102   Amit  30.0  Mumbai  60000.0
# 2          103  Sneha   NaN    Pune  55000.0
# 3          104  Priya  28.0   Delhi      NaN
# 4          105  Kiran  40.0  Mumbai  65000.0

# %%
# Convert DataFrame to CSV

# %%
df.to_csv("customer_data.csv", index=False)

# %%
# Load Dataset from CSV

# %%
df = pd.read_csv("customer_data.csv")
print(df)
# Out:
#    Customer_ID   Name   Age    City   Salary
# 0          101  Rahul  25.0    Pune  50000.0
# 1          102   Amit  30.0  Mumbai  60000.0
# 2          103  Sneha   NaN    Pune  55000.0
# 3          104  Priya  28.0   Delhi      NaN
# 4          105  Kiran  40.0  Mumbai  65000.0

# %%
# Data Understanding (EDA)

# %%
print(df.head())
# Out:
#    Customer_ID   Name   Age    City   Salary
# 0          101  Rahul  25.0    Pune  50000.0
# 1          102   Amit  30.0  Mumbai  60000.0
# 2          103  Sneha   NaN    Pune  55000.0
# 3          104  Priya  28.0   Delhi      NaN
# 4          105  Kiran  40.0  Mumbai  65000.0

# %%
print(df.tail())
# Out:
#    Customer_ID   Name   Age    City   Salary
# 0          101  Rahul  25.0    Pune  50000.0
# 1          102   Amit  30.0  Mumbai  60000.0
# 2          103  Sneha   NaN    Pune  55000.0
# 3          104  Priya  28.0   Delhi      NaN
# 4          105  Kiran  40.0  Mumbai  65000.0

# %%
print(df.shape)
# Out:
# (5, 5)

# %%
print(df.columns)
# Out:
# Index(['Customer_ID', 'Name', 'Age', 'City', 'Salary'], dtype='str')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_ID  5 non-null      int64
#  1   Name         5 non-null      str
#  2   Age          4 non-null      float64
#  3   City         5 non-null      str
#  4   Salary       4 non-null      float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 328.0 bytes
# None

# %%
print(df.describe())
# Out:
#        Customer_ID    Age        Salary
# count     5.000000   4.00      4.000000
# mean    103.000000  30.75  57500.000000
# std       1.581139   6.50   6454.972244
# min     101.000000  25.00  50000.000000
# 25%     102.000000  27.25  53750.000000
# 50%     103.000000  29.00  57500.000000
# 75%     104.000000  32.50  61250.000000
# max     105.000000  40.00  65000.000000

# %%
# Handling Missing Values

# %%
print(df.isnull().sum())
# Out:
# Customer_ID    0
# Name           0
# Age            1
# City           0
# Salary         1
# dtype: int64

# %%
# Fill missing values

# %%
# Fill Age with mean
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#    Customer_ID   Name    Age    City   Salary
# 0          101  Rahul  25.00    Pune  50000.0
# 1          102   Amit  30.00  Mumbai  60000.0
# 2          103  Sneha  30.75    Pune  55000.0
# 3          104  Priya  28.00   Delhi      NaN
# 4          105  Kiran  40.00  Mumbai  65000.0

# %%
# Fill Salary with median
df["Salary"] = df["Salary"].fillna(df["Salary"].median())

# %%
# Data Cleaning

# %%
df = df.drop_duplicates()

# %%
df.rename(columns={"Name": "Customer_Name"}, inplace=True)

# %%
df
# Out:
#    Customer_ID Customer_Name    Age    City   Salary
# 0          101         Rahul  25.00    Pune  50000.0
# 1          102          Amit  30.00  Mumbai  60000.0
# 2          103         Sneha  30.75    Pune  55000.0
# 3          104         Priya  28.00   Delhi  57500.0
# 4          105         Kiran  40.00  Mumbai  65000.0

# %%
# Change datatype

# %%
df["Age"] = df["Age"].astype(int)

# %%
# Filtering Data

# %%
# Customers with Salary > 55000
high_salary = df[df["Salary"] > 55000]
print(high_salary)
# Out:
#    Customer_ID Customer_Name  Age    City   Salary
# 1          102          Amit   30  Mumbai  60000.0
# 3          104         Priya   28   Delhi  57500.0
# 4          105         Kiran   40  Mumbai  65000.0

# %%
# Selecting Data

# %%
# Single column
print(df["Customer_Name"])
# Out:
# 0    Rahul
# 1     Amit
# 2    Sneha
# 3    Priya
# 4    Kiran
# Name: Customer_Name, dtype: str

# %%
# Multiple columns
print(df[["Customer_Name", "Salary"]])
# Out:
#   Customer_Name   Salary
# 0         Rahul  50000.0
# 1          Amit  60000.0
# 2         Sneha  55000.0
# 3         Priya  57500.0
# 4         Kiran  65000.0

# %%
# Row selection
print(df.iloc[0])  # first row
# Out:
# Customer_ID          101
# Customer_Name      Rahul
# Age                   25
# City                Pune
# Salary           50000.0
# Name: 0, dtype: object

# %%
# Sorting Data

# %%
df = df.sort_values(by="Salary", ascending=False)

# %%
df
# Out:
#    Customer_ID Customer_Name  Age    City   Salary
# 4          105         Kiran   40  Mumbai  65000.0
# 1          102          Amit   30  Mumbai  60000.0
# 3          104         Priya   28   Delhi  57500.0
# 2          103         Sneha   30    Pune  55000.0
# 0          101         Rahul   25    Pune  50000.0

# %%
# Merge Data

# %%
df1 = pd.DataFrame({
    "Customer_ID": [101, 102],
    "Product": ["Car", "Bike"]
})

merged = pd.merge(df, df1, on="Customer_ID", how="left")
print(merged)
# Out:
#    Customer_ID Customer_Name  Age    City   Salary Product
# 0          105         Kiran   40  Mumbai  65000.0     NaN
# 1          102          Amit   30  Mumbai  60000.0    Bike
# 2          104         Priya   28   Delhi  57500.0     NaN
# 3          103         Sneha   30    Pune  55000.0     NaN
# 4          101         Rahul   25    Pune  50000.0     Car

# %%
df1
# Out:
#    Customer_ID Product
# 0          101     Car
# 1          102    Bike

# %%
# Apply Function

# %%
def tax(salary):
    return salary * 0.05

df["Tax"] = df["Salary"].apply(tax)

# %%
df
# Out:
#    Customer_ID Customer_Name  Age    City   Salary     Tax
# 4          105         Kiran   40  Mumbai  65000.0  3250.0
# 1          102          Amit   30  Mumbai  60000.0  3000.0
# 3          104         Priya   28   Delhi  57500.0  2875.0
# 2          103         Sneha   30    Pune  55000.0  2750.0
# 0          101         Rahul   25    Pune  50000.0  2500.0
